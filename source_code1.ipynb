# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.metrics import mean_squared_error, mean_absolute_error
from datetime import datetime
import os

folder_path = 'processing_1'
folder_path2 = 'processing_2'
folder_path3 = 'merged_dataset'

# %% [markdown]
# ## Processing Part 1

# %% [markdown]
# #### Concate the irrigation files

# %%
irri_2 = pd.read_csv("dataset/Irrigation_2.csv", sep = ';', encoding='ISO-8859-1', index_col=False)
irri_3 = pd.read_csv("dataset/Irrigation_3.csv", sep = ';', encoding='ISO-8859-1', index_col=False)
irri_4 = pd.read_csv("dataset/Irrigation_4.csv", sep = ';', encoding='ISO-8859-1', index_col=False)
irri_5 = pd.read_csv("dataset/Irrigation_5.csv", sep = ';', encoding='ISO-8859-1', index_col=False)
irri_6 = pd.read_csv("dataset/Irrigation_6.csv", sep = ';', encoding='ISO-8859-1', index_col=False)
irri_7 = pd.read_csv("dataset/Irrigation_7.csv", sep = ';', encoding='ISO-8859-1', index_col=False)
irri_8 = pd.read_csv("dataset/Irrigation_8.csv", sep = ';', encoding='ISO-8859-1', index_col=False)
irri_9 = pd.read_csv("dataset/Irrigation_9.csv", sep = ';', encoding='ISO-8859-1', index_col=False)

# %%
irri_2
# Out:
#       Campagne Region                 Site Famille Variete Num Parcelle  \
# 0        20/21  GHARB  Douar Oued Mahdouma      AF     AF1        11011
# 1        20/21  GHARB  Douar Oued Mahdouma      AF     AF1        11011
# 2        20/21  GHARB  Douar Oued Mahdouma      AF     AF1        11011
# 3        20/21  GHARB  Douar Oued Mahdouma      AF     AF1        11011
# 4        20/21  GHARB  Douar Oued Mahdouma      AF     AF1        11011
# ...        ...    ...                  ...     ...     ...          ...
# 64994    20/21  HAOUZ         Ouled Moussa      AF     AF1       50171
# 64995    20/21  HAOUZ         Ouled Moussa      AF     AF1       50171
# 64996    20/21  HAOUZ         Ouled Moussa      AF     AF1       50171
# 64997    20/21  HAOUZ         Ouled Moussa      AF     AF1       50171
# 64998    20/21  HAOUZ         Ouled Moussa      AF     AF1       50171
#
#       Code Traçabilité      Date Qté eau (m3)
# 0              TR11011  01/10/20     185,4000
# ...

# %%
irri_3
# Out:
#       Campagne Region          Site Famille Variete  Num Parcelle  \
# 0        20/21  HAOUZ  Ouled Moussa      AF     AF1         50171
# 1        20/21  HAOUZ  Ouled Moussa      AF     AF1         50171
# 2        20/21  HAOUZ  Ouled Moussa      AF     AF1         50171
# 3        20/21  HAOUZ  Ouled Moussa      AF     AF1         50171
# 4        20/21  HAOUZ  Ouled Moussa      AF     AF1         50171
# ...        ...    ...           ...     ...     ...           ...
# 64994    20/21  TADLA      Bni Ayat     ORA    ORA1         20306
# 64995    20/21  TADLA      Bni Ayat     ORA    ORA1         20306
# 64996    20/21  TADLA      Bni Ayat     ORA    ORA1         20306
# 64997    20/21  TADLA      Bni Ayat     ORA    ORA1         20306
# 64998    20/21  TADLA      Bni Ayat     ORA    ORA1         20306
#
#       Code Traçabilité      Date Qté eau (m3)
# 0              TR50000  04/09/21      47,1055
# 1              TR50000  05/09/21      47,2955
# ...

# %%
irri_dict = {
    4: irri_4,
    5: irri_5,
    6: irri_6,
    7: irri_7,
    8: irri_8,
    9: irri_9
}

combined_irri = pd.concat([irri_2, irri_3], ignore_index=True)

for i in range(4, 10):
    combined_irri = pd.concat([combined_irri, irri_dict[i]], ignore_index=True)

# %%
combined_irri
# Out:
#        Campagne Region                 Site Famille Variete Num Parcelle  \
# 0         20/21  GHARB  Douar Oued Mahdouma      AF     AF1        11011
# 1         20/21  GHARB  Douar Oued Mahdouma      AF     AF1        11011
# 2         20/21  GHARB  Douar Oued Mahdouma      AF     AF1        11011
# 3         20/21  GHARB  Douar Oued Mahdouma      AF     AF1        11011
# 4         20/21  GHARB  Douar Oued Mahdouma      AF     AF1        11011
# ...         ...    ...                  ...     ...     ...          ...
# 519987      NaN    NaN                  NaN     NaN     NaN          NaN
# 519988      NaN    NaN                  NaN     NaN     NaN          NaN
# 519989      NaN    NaN                  NaN     NaN     NaN          NaN
# 519990      NaN    NaN                  NaN     NaN     NaN          NaN
# 519991      NaN    NaN                  NaN     NaN     NaN          NaN
#
#        Code Traçabilité      Date Qté eau (m3)
# ...

# %%
## Saving i the folder processing_1
# Ensure the folder exists
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# Specify the full file path (folder path + file name)
file_path = os.path.join(folder_path, 'combined_irrigation.csv')

# Save the DataFrame to a CSV file
combined_irri.to_csv(file_path, index=False)

# %% [markdown]
# #### Concate the Apports N.P.K files

# %%
Apports_NPK_10 = pd.read_csv("dataset/Apports N.P.K_10.csv", sep = ';', encoding='ISO-8859-1', index_col=False)
Apports_NPK_11 = pd.read_csv("dataset/Apports N.P.K_11.csv", sep = ';', encoding='ISO-8859-1', index_col=False)
Apports_NPK_12 = pd.read_csv("dataset/Apports N.P.K_12.csv", sep = ';', encoding='ISO-8859-1', index_col=False)

# %%
combined_apport = pd.concat([Apports_NPK_10, Apports_NPK_11], ignore_index=True)
combined_apport = pd.concat([combined_apport, Apports_NPK_12], ignore_index=True)

# %%
Apports_NPK_12
# Out:
#       Campagne Region          Site Famille Variete  Num Parcelle  \
# 0        22/23  HAOUZ  Ouled Moussa      AF     AF1       40258.0
# 1        22/23  HAOUZ  Ouled Moussa      AF     AF1       40258.0
# 2        22/23  HAOUZ  Ouled Moussa      AF     AF1       40258.0
# 3        22/23  HAOUZ  Ouled Moussa      AF     AF1       40258.0
# 4        22/23  HAOUZ  Ouled Moussa      AF     AF1       40258.0
# ...        ...    ...           ...     ...     ...           ...
# 64994      NaN    NaN           NaN     NaN     NaN           NaN
# 64995      NaN    NaN           NaN     NaN     NaN           NaN
# 64996      NaN    NaN           NaN     NaN     NaN           NaN
# 64997      NaN    NaN           NaN     NaN     NaN           NaN
# 64998      NaN    NaN           NaN     NaN     NaN           NaN
#
#       CodeTracabilite      Date           N    P         K
# 0             TR40300  01/08/23  1,87979505    0  2,447655
# ...

# %%
combined_apport
# Out:
#        Campagne Region                 Site Famille Variete Num Parcelle  \
# 0         20/21  GHARB  Douar Oued Mahdouma      AF     AF1        11011
# 1         20/21  GHARB  Douar Oued Mahdouma      AF     AF1        11011
# 2         20/21  GHARB  Douar Oued Mahdouma      AF     AF1        11011
# 3         20/21  GHARB  Douar Oued Mahdouma      AF     AF1        11011
# 4         20/21  GHARB  Douar Oued Mahdouma      AF     AF1        11011
# ...         ...    ...                  ...     ...     ...          ...
# 194992      NaN    NaN                  NaN     NaN     NaN          NaN
# 194993      NaN    NaN                  NaN     NaN     NaN          NaN
# 194994      NaN    NaN                  NaN     NaN     NaN          NaN
# 194995      NaN    NaN                  NaN     NaN     NaN          NaN
# 194996      NaN    NaN                  NaN     NaN     NaN          NaN
#
#        CodeTracabilite      Date      N       P     K
# ...

# %%
# Ensure the folder exists
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# Specify the full file path (folder path + file name)
file_path = os.path.join(folder_path, 'combined_Apports_NPK.csv')

# Save the DataFrame to a CSV file
combined_apport.to_csv(file_path, index=False)

# %% [markdown]
# #### Processing the test and training set

# %%
train = pd.read_csv("dataset/train.csv", sep = ';', index_col=False)
test = pd.read_csv("dataset/test.csv", sep = ';', index_col=False)

# %%
train['is_train'] = True
test['is_train'] = False

# %%
train_test = pd.concat([train, test], ignore_index=True)

# %%
train_test
# Out:
#        Id Campagne Region             Site Famille Variete Num Parcelle  \
# 0       1    20/21  GHARB  Chorf Laghouazi     CLA    CLA1        13030
# 1       2    20/21  GHARB  Chorf Laghouazi     CLA    CLA6        18030
# 2       3    20/21  GHARB  Chorf Laghouazi     CLA   CLA12        13010
# 3       4    20/21  GHARB  Chorf Laghouazi     CLA   CLA14        12010
# 4       5    20/21  GHARB  Chorf Laghouazi     CLA   CLA14        12020
# ...   ...      ...    ...              ...     ...     ...          ...
# 3895  777    22/23  SOUSS      Ouled Abbou     SPA    SPA4        21071
# 3896  778    22/23  SOUSS      Ouled Abbou     SPA    SPA5        21021
# 3897  779    22/23  SOUSS      Ouled Abbou     SPA    SPA6        21121
# 3898  780    22/23  SOUSS      Ouled Abbou     SPA    SPA7        21081
# 3899  781    22/23  SOUSS      Ouled Abbou     SPA   SPA11        21011
#
#      CodeTracabilite        Date      Tonnage  is_train
# ...

# %%
# Ensure the folder exists
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# Specify the full file path (folder path + file name)
file_path = os.path.join(folder_path, 'train_test.csv')

# Save the DataFrame to a CSV file
train_test.to_csv(file_path, index=False)

# %% [markdown]
# ## Processing: Part 2

# %% [markdown]
# #### (tkhrebi9): Make the visuaisation of the test_training set

# %%
train_test = pd.read_csv("processing_1/train_test.csv", index_col=False)

# %%
train_test
# Out:
#        Id Campagne Region             Site Famille Variete Num Parcelle  \
# 0       1    20/21  GHARB  Chorf Laghouazi     CLA    CLA1        13030
# 1       2    20/21  GHARB  Chorf Laghouazi     CLA    CLA6        18030
# 2       3    20/21  GHARB  Chorf Laghouazi     CLA   CLA12        13010
# 3       4    20/21  GHARB  Chorf Laghouazi     CLA   CLA14        12010
# 4       5    20/21  GHARB  Chorf Laghouazi     CLA   CLA14        12020
# ...   ...      ...    ...              ...     ...     ...          ...
# 3895  777    22/23  SOUSS      Ouled Abbou     SPA    SPA4        21071
# 3896  778    22/23  SOUSS      Ouled Abbou     SPA    SPA5        21021
# 3897  779    22/23  SOUSS      Ouled Abbou     SPA    SPA6        21121
# 3898  780    22/23  SOUSS      Ouled Abbou     SPA    SPA7        21081
# 3899  781    22/23  SOUSS      Ouled Abbou     SPA   SPA11        21011
#
#      CodeTracabilite        Date      Tonnage  is_train
# ...

# %%
# Make a copy of the filtered data to avoid SettingWithCopyWarning
filtered_data = train_test[train_test['is_train'] == True].copy()

# Extract the year and avoid the warning
filtered_data.loc[:, 'Year'] = pd.to_datetime(filtered_data['Date']).dt.year

grouped = filtered_data.groupby(['Variete', 'CodeTracabilite', 'Year']).size()
multiple_occurrences = grouped[grouped > 1]
if multiple_occurrences.empty:
    print("All visualizations where is_train is True are made once a year.")
else:
    print("Some visualizations where is_train is True are made more than once a year:")
    print(multiple_occurrences)
# Out:
# Some visualizations where is_train is True are made more than once a year:
# Variete  CodeTracabilite  Year
# AF1      TR10000          2021    29
#                           2022    27
#          TR11000          2021    60
#                           2022    41
#          TR11011          2021     2
#                                   ..
# SPA8     TR21061          2021     6
#                           2022     7
# SPA9     TR21091          2020     2
#                           2021     3
#                           2022     2
# Length: 542, dtype: int64

# %%
# Your multiple occurrences Series, replace this with your actual data
multiple_occurrences = grouped[grouped > 1]

# Convert the Series to a DataFrame
multiple_occurrences = multiple_occurrences.reset_index(name='Count')

# Ensure the folder exists
if not os.path.exists(folder_path2):
    os.makedirs(folder_path2)

# Specify the full file path (folder path + file name)
file_path = os.path.join(folder_path2, 'multiple_occurrences_train.csv')

# Save the DataFrame to a CSV file
multiple_occurrences.to_csv(file_path, index=False)

# %%
# Make a copy of the filtered data to avoid SettingWithCopyWarning
filtered_data = train_test[train_test['is_train'] == False].copy()

# Extract the year and avoid the warning
filtered_data.loc[:, 'Year'] = pd.to_datetime(filtered_data['Date']).dt.year

grouped = filtered_data.groupby(['Variete', 'Num Parcelle', 'CodeTracabilite', 'Year']).size()
multiple_occurrences = grouped[grouped > 1]
if multiple_occurrences.empty:
    print("All visualizations where is_train is True are made once a year.")
else:
    print("Some visualizations where is_train is True are made more than once a year:")
    print(multiple_occurrences)

# Your multiple occurrences Series, replace this with your actual data
multiple_occurrences = grouped[grouped > 1]

# Convert the Series to a DataFrame
multiple_occurrences = multiple_occurrences.reset_index(name='Count')

# Ensure the folder exists
if not os.path.exists(folder_path2):
    os.makedirs(folder_path2)

# Specify the full file path (folder path + file name)
file_path = os.path.join(folder_path2, 'multiple_occurrences_test.csv')

# Save the DataFrame to a CSV file
multiple_occurrences.to_csv(file_path, index=False)
# Out:
# Some visualizations where is_train is True are made more than once a year:
# Variete  Num Parcelle  CodeTracabilite  Year
# AF1      10001         TR21010          2023    2
#          10007         TR22141          2023    4
#          10008         TR22220          2023    4
#          10009         TR21040          2023    4
#          10010         TR30099          2023    4
#                                                ..
# SPA5     21021         TR21021          2023    4
# SPA6     21121         TR21121          2023    8
# SPA7     21081         TR21081          2023    5
#          32130         TR31401          2023    2
# SPA8     21061         TR21061          2023    4
# Length: 220, dtype: int64

# %%
train_test = train_test.drop(columns='Id')
train_test["Date"] = pd.to_datetime(train_test["Date"])
train_test['Tonnage'] = train_test['Tonnage'].str.replace(',', '.').astype(float)

# %%
# hado ga3 li occuraw many times, i'll take the best tonnage and drop the others
train_test.dtypes
# Out:
# Campagne                   object
# Region                     object
# Site                       object
# Famille                    object
# Variete                    object
# Num Parcelle               object
# CodeTracabilite            object
# Date               datetime64[ns]
# Tonnage                   float64
# is_train                     bool
# dtype: object

# %% [markdown]
# #### irrigation yearly

# %%
# Load the dataset
combined_irrigation = pd.read_csv("processing_1/combined_irrigation.csv", index_col=False)

# Clean the 'Qté eau (m3)' column
combined_irrigation['Qté eau (m3)'] = combined_irrigation['Qté eau (m3)'].str.replace(',', '.')
combined_irrigation['Qté eau (m3)'] = combined_irrigation['Qté eau (m3)'].str.replace(r'[^\d.-]', '', regex=True).astype(float)

# Convert the 'Date' column to datetime format and extract the year
combined_irrigation['Date'] = pd.to_datetime(combined_irrigation['Date'])
# Out:
# C:\Users\DataScience\AppData\Local\Temp\ipykernel_43940\2176009334.py:4: DtypeWarning: Columns (0,1,2,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_irrigation = pd.read_csv("processing_1/combined_irrigation.csv", index_col=False)
# C:\Users\DataScience\AppData\Local\Temp\ipykernel_43940\2176009334.py:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   combined_irrigation['Date'] = pd.to_datetime(combined_irrigation['Date'])
#      Year Campagne Region             Site Famille Variete Num Parcelle  \
# 0  2020.0    20/21  GHARB      Ben Mansour      AF     AF1        11240
# 1  2020.0    20/21  GHARB      Ben Mansour     CLA   CLA14        11211
# 2  2020.0    20/21  GHARB      Ben Mansour     CLA   CLA16        11160
# 3  2020.0    20/21  GHARB      Ben Mansour     ORA    ORA2        11170
# ...

# %%
combined_irrigation['Year'] = combined_irrigation['Date'].dt.year

# Calculate the yearly average of 'Qté eau (m3)' for each combination of the other columns
grouped_irrigation = combined_irrigation.groupby(['Year', 'Campagne', 'Region', 'Site', 'Famille', 'Variete', 'Num Parcelle', 'Code Traçabilité'])['Qté eau (m3)'].mean().reset_index()

# Rename the 'Qté eau (m3)' column to 'yearly_average'
grouped_irrigation.rename(columns={'Qté eau (m3)': 'yearly_average_of_qte_d_eau'}, inplace=True)

# Now grouped_irrigation has the structure you want
grouped_irrigation.head()

# %%
# Ensure the folder exists
if not os.path.exists(folder_path2):
    os.makedirs(folder_path2)

# Specify the full file path (folder path + file name)
file_path = os.path.join(folder_path2, 'irrigation_yearly.csv')

# Save the DataFrame to a CSV file
grouped_irrigation.to_csv(file_path, index=False)
# Out:
# Data successfully saved to processing_2\irrigation_yearly.csv

# %% [markdown]
# #### Apport NPK yearly

# %%
combined_Apports_NPK = pd.read_csv("processing_1\combined_Apports_NPK.csv", index_col=False)

# Clean the 'Qté eau (m3)' column
combined_Apports_NPK['N'] = combined_Apports_NPK['N'].str.replace(',', '.')
combined_Apports_NPK['N'] = combined_Apports_NPK['N'].str.replace(r'[^\d.-]', '', regex=True).astype(float)

combined_Apports_NPK['P'] = combined_Apports_NPK['P'].str.replace(',', '.')
combined_Apports_NPK['P'] = combined_Apports_NPK['P'].str.replace(r'[^\d.-]', '', regex=True).astype(float)

combined_Apports_NPK['K'] = combined_Apports_NPK['K'].str.replace(',', '.')
combined_Apports_NPK['K'] = combined_Apports_NPK['K'].str.replace(r'[^\d.-]', '', regex=True).astype(float)

# Convert the 'Date' column to datetime format and extract the year
combined_Apports_NPK['Date'] = pd.to_datetime(combined_Apports_NPK['Date'])
# Out:
# C:\Users\DataScience\AppData\Local\Temp\ipykernel_43940\1201804648.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_Apports_NPK = pd.read_csv("processing_1\combined_Apports_NPK.csv", index_col=False)
# C:\Users\DataScience\AppData\Local\Temp\ipykernel_43940\1201804648.py:14: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   combined_Apports_NPK['Date'] = pd.to_datetime(combined_Apports_NPK['Date'])

# %%
combined_Apports_NPK['Year'] = combined_Apports_NPK['Date'].dt.year

# Calculate the yearly average of 'N', 'P', and 'K' for each combination of the other columns
grouped_Apports_NPK = combined_Apports_NPK.groupby(['Year', 'Campagne', 'Region', 'Site', 'Famille', 'Variete', 'Num Parcelle', 'CodeTracabilite'])[['N', 'P', 'K']].mean().reset_index()

# Rename the columns to indicate they are yearly averages
grouped_Apports_NPK.rename(columns={
    'N': 'yearly_average_N',
    'P': 'yearly_average_P',
    'K': 'yearly_average_K'}, inplace=True)

# View the first few rows of the resulting DataFrame
grouped_Apports_NPK.head()
# Out:
#      Year Campagne Region             Site Famille Variete Num Parcelle  \
# 0  2020.0    20/21  GHARB      Ben Mansour      AF     AF1        11240
# 1  2020.0    20/21  GHARB  Chorf Laghouazi     CLA    CLA1        13030
# 2  2020.0    20/21  GHARB  Chorf Laghouazi     CLA   CLA12        13010
# 3  2020.0    20/21  GHARB  Chorf Laghouazi     CLA   CLA14        12010
# 4  2020.0    20/21  GHARB  Chorf Laghouazi     CLA   CLA14        12010
#
#   CodeTracabilite  yearly_average_N  yearly_average_P  yearly_average_K
# 0         TR11240          3.900000          0.000000         13.800000
# 1         TR11130         10.173809          2.322643          0.000000
# 2         TR11120         14.827290          3.385015          0.000000
# 3         TR11020          2.308023          0.000000          0.005855
# 4         TR11090         30.184731         10.290462          0.116327

# %%
# Ensure the folder exists
if not os.path.exists(folder_path2):
    os.makedirs(folder_path2)

# Specify the full file path (folder path + file name)
file_path = os.path.join(folder_path2, 'Apports_NPK_yearly.csv')

# Save the DataFrame to a CSV file
grouped_Apports_NPK.to_csv(file_path, index=False)

# %% [markdown]
# #### train_test yearly

# %%
train_test = pd.read_csv("processing_1/train_test.csv", index_col=False)

# %%
train_test = train_test.drop(columns='Id')
train_test["Date"] = pd.to_datetime(train_test["Date"])
train_test['Tonnage'] = train_test['Tonnage'].str.replace(',', '.').astype(float)

# %%
train_test['Year'] = train_test['Date'].dt.year

# Calculate the yearly average of 'Qté eau (m3)' for each combination of the other columns
grouped_train_test = train_test.groupby(['Year', 'Campagne', 'Region', 'Site', 'Famille', 'Variete', 'Num Parcelle', 'CodeTracabilite'])['Tonnage'].mean().reset_index()

# Rename the 'Qté eau (m3)' column to 'yearly_average'
grouped_train_test.rename(columns={'Tonnage': 'yearly_average_tonnage'}, inplace=True)

# Now grouped_irrigation has the structure you want
grouped_train_test.head()
# Out:
#    Year Campagne Region         Site Famille Variete Num Parcelle  \
# 0  2020    20/21  GHARB  Ben Mansour      AF     AF1        11240
# 1  2020    20/21  GHARB  Ben Mansour     CLA   CLA13        11130
# 2  2020    20/21  GHARB  Ben Mansour     CLA   CLA13        11212
# 3  2020    20/21  GHARB  Ben Mansour     CLA   CLA14        11211
# 4  2020    20/21  GHARB  Ben Mansour     CLA   CLA15        11140
#
#   CodeTracabilite  yearly_average_tonnage
# 0         TR11240               161.00000
# 1         TR11130             36082.22357
# 2         TR11212             48051.99275
# 3         TR11211             21549.73456
# 4         TR11140             23220.26750

# %%
# Ensure the folder exists
if not os.path.exists(folder_path2):
    os.makedirs(folder_path2)

# Specify the full file path (folder path + file name)
file_path = os.path.join(folder_path2, 'train_test_yearly.csv')

# Save the DataFrame to a CSV file
grouped_train_test.to_csv(file_path, index=False)

# %% [markdown]
# ## Merge the dataset

# %%
train_test_yearly = pd.read_csv("processing_2/train_test_yearly.csv", index_col=False)
Apports_NPK_yearly = pd.read_csv("processing_2/Apports_NPK_yearly.csv", index_col=False)
irrigation_yearly = pd.read_csv("processing_2/irrigation_yearly.csv", index_col=False)


# Rename the column
irrigation_yearly.rename(columns={'Code Traçabilité': 'CodeTracabilite'}, inplace=True)

# Save the updated DataFrame back to a CSV file
irrigation_yearly.to_csv('processing_2/irrigation_yearly.csv', index=False)

# %%
# Merge the datasets
# First, merge 'train_test_yearly' and 'Apports_NPK_yearly'
merged_1 = pd.merge(train_test_yearly, Apports_NPK_yearly, 
                    how='inner', 
                    left_on=['CodeTracabilite', 'Variete', 'Year', 'Campagne', 'Site', 'Famille', 'Num Parcelle', 'Region'], 
                    right_on=['CodeTracabilite', 'Variete', 'Year', 'Campagne', 'Site', 'Famille', 'Num Parcelle', 'Region'])

# Now, merge the result with 'irrigation_yearly'
test_train_merged = pd.merge(merged_1, irrigation_yearly, 
                        how='outer', 
                        left_on=['CodeTracabilite', 'Variete', 'Year', 'Campagne', 'Site', 'Famille', 'Num Parcelle', 'Region'], 
                        right_on=['CodeTracabilite', 'Variete', 'Year', 'Campagne', 'Site', 'Famille', 'Num Parcelle', 'Region'])

# Check the first few rows of the final merged dataset
test_train_merged.head()
# Out:
#      Year Campagne Region             Site Famille Variete Num Parcelle  \
# 0  2020.0    20/21  GHARB      Ben Mansour      AF     AF1        11240
# 1  2020.0    20/21  GHARB  Chorf Laghouazi     CLA    CLA1        13030
# 2  2020.0    20/21  GHARB  Chorf Laghouazi     CLA   CLA12        13010
# 3  2020.0    20/21  GHARB  Chorf Laghouazi     CLA   CLA14        12010
# 4  2020.0    20/21  GHARB  Chorf Laghouazi     CLA   CLA14        12010
#
#   CodeTracabilite  yearly_average_tonnage  yearly_average_N  yearly_average_P  \
# 0         TR11240              161.000000          3.900000          0.000000
# 1         TR11130              269.855000         10.173809          2.322643
# 2         TR11120            36952.604000         14.827290          3.385015
# 3         TR11020             3334.412000          2.308023          0.000000
# 4         TR11090            24822.642835         30.184731         10.290462
#
#    yearly_average_K  yearly_average_of_qte_d_eau
# ...

# %%
# Ensure the folder exists
if not os.path.exists(folder_path3):
    os.makedirs(folder_path3)

# Specify the full file path (folder path + file name)
file_path = os.path.join(folder_path3, 'train_test_merged.csv')

# Save the DataFrame to a CSV file
test_train_merged.to_csv(file_path, index=False)

# %% [markdown]
# ## Data cleaning

# %%
train.shape
# Out:
# (3119, 11)

# %%
train_test_merged = pd.read_csv("merged_dataset/train_test_merged.csv", index_col=False)

# %%
train_test_merged.shape
# Out:
# (4086, 13)

# %%
# Convert the 'Year' column to a string first if it's not already
train_test_merged['Year'] =train_test_merged['Year'].astype(int)

# Add '-01-01' to make it a full date (January 1st of that year)
train_test_merged['Year'] =train_test_merged['Year'].astype(str) + '-01-01'

# Now convert the 'Year' column to datetime
train_test_merged['Year'] = pd.to_datetime(train_test_merged['Year'])

# %%
train_test_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4086 entries, 0 to 4085
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         4086 non-null   datetime64[ns]
#  1   Campagne                     4086 non-null   object
#  2   Region                       4086 non-null   object
#  3   Site                         4086 non-null   object
#  4   Famille                      4086 non-null   object
#  5   Variete                      4086 non-null   object
#  6   Num Parcelle                 4086 non-null   object
#  7   CodeTracabilite              4086 non-null   object
#  8   yearly_average_tonnage       1041 non-null   float64
#  9   yearly_average_N             1216 non-null   float64
#  10  yearly_average_P             1216 non-null   float64
#  11  yearly_average_K             1216 non-null   float64
# ...

# %%
# Detecting duplicates
duplicates = train_test_merged[train_test_merged.duplicated()]
duplicates
# Out:
# Empty DataFrame
# Columns: [Year, Campagne, Region, Site, Famille, Variete, Num Parcelle, CodeTracabilite, yearly_average_tonnage, yearly_average_N, yearly_average_P, yearly_average_K, yearly_average_of_qte_d_eau]
# Index: []

# %%
train_test_merged.isnull().sum()  ##none null value
# Out:
# Year                              0
# Campagne                          0
# Region                            0
# Site                              0
# Famille                           0
# Variete                           0
# Num Parcelle                      0
# CodeTracabilite                   0
# yearly_average_tonnage         3045
# yearly_average_N               2870
# yearly_average_P               2870
# yearly_average_K               2870
# yearly_average_of_qte_d_eau      18
# dtype: int64

# %%
train_test_merged.tail(3000)
# Out:
#            Year Campagne Region              Site Famille Variete  \
# 1086 2023-01-01    22/23  HAOUZ   Douar Ahl quadi     ORA   ORA11
# 1087 2023-01-01    22/23  HAOUZ   Douar Ahl quadi     ORA    ORA2
# 1088 2023-01-01    22/23  HAOUZ   Douar Ahl quadi     SPA    SPA2
# 1089 2023-01-01    22/23  HAOUZ  Lalla Takerkoust      AF     AF1
# 1090 2023-01-01    22/23  HAOUZ  Lalla Takerkoust      AF     AF1
# ...         ...      ...    ...               ...     ...     ...
# 4081 2023-01-01    22/23  TADLA          Bni Ayat     ORA    ORA6
# 4082 2023-01-01    22/23  TADLA          Bni Ayat     ORA    ORA6
# 4083 2023-01-01    22/23  TADLA          Bni Ayat     ORA    ORA9
# 4084 2023-01-01    22/23  TADLA          Bni Ayat     SPA    SPA1
# 4085 2023-01-01    22/23  TADLA          Bni Ayat     SPA    SPA1
#
#      Num Parcelle CodeTracabilite  yearly_average_tonnage  yearly_average_N  \
# 1086        21043         TR21043                     NaN         29.150777
# ...
